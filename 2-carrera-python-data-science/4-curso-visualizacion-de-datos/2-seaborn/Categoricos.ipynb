# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = sns.load_dataset('titanic')
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x = 'pclass', y = 'age', data = data, height=7, kind='swarm', hue='sex');

# %%
fig, ax = plt.subplots(figsize = (10, 5))
sns.boxplot(x = 'pclass', y = 'age', data = data, ax = ax, hue='sex');

# %% [markdown]
# [Qué significa](https://camo.githubusercontent.com/6c5b9530817ab5f2edaf09ea69bfffec7ed55d3cb87a0677ee6d0fc3416f9711/68747470733a2f2f6d69726f2e6d656469756d2e636f6d2f6d61782f31383030302f312a32633231536b7a4a4d6633667250585041525f675a412e706e67)

# %%
sns.catplot(x = 'pclass', y = 'age', data = data, hue = 'sex', kind = 'boxen', height=8);

# %%
sns.catplot(x = 'pclass', y = 'survived', hue = 'sex', data = data, kind = 'bar', estimator=np.count_nonzero)
