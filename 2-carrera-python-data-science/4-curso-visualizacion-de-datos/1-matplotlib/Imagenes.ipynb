# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# Anyadimos este import
import matplotlib.image as mpimg
import urllib.request

import warnings
warnings.filterwarnings('ignore')

from pathlib import Path

data_path = Path('./data')

# %matplotlib inline

# %%
image = mpimg.PIL.Image.open(urllib.request.urlopen("https://raw.githubusercontent.com/tphinkle/tphinkle.github.io/master/images/2017-8-15/mnist_0.png"))
plt.imshow(image)

# %%
from matplotlib.colors import Colormap

# %%
pix = np.array(image)
plt.imshow(pix[:,:,0], cmap='hot')
