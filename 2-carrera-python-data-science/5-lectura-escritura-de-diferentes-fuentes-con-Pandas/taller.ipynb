# %%
import pandas as pd

# %% [markdown]
# # csv
# * `sep`: Separador de elementos
# * `header`: La línea del fichero donde están las cabeceras
# * `na_values`: Indicamos qué valores son nulos
# * `compression`: Indica el tipo de compresión del fichero, `{‘infer’, ‘gzip’, ‘bz2’, ‘zip’, ‘xz’, None}, default ‘infer’`
# * `decimal`: Indicamos el separador de decimales
# * `encoding`: Indica la codificación del fichero

# %%
data_folder_in = "./datos/in/{}"
data_folder_out = "./datos/out/{}"

iconos = 'iconos.csv'
iconos_zip = 'iconos.zip'
puntuaciones = 'puntuaciones.csv'

url = 'https://opendata.arcgis.com/datasets/828179cabe6f479691b08560f41af197_0.csv'

# %%
pd.read_csv(url)
# Out:
#      OBJECTID  codine             AMBITO   Censo  Votantes  Nulos  Válidos  \
# 0           1    1001   ALEGRÍA-DULANTZI  1986.0    1177.0    8.0   1169.0
# 1           2    1002            AMURRIO  8120.0    5574.0   44.0   5530.0
# 2           3    1003            ARAMAIO  1191.0     839.0    2.0    837.0
# 3           4    1004         ARTZINIEGA  1408.0     947.0   11.0    936.0
# 4           5    1006            ARMIÑÓN   174.0     110.0    3.0    107.0
# ..        ...     ...                ...     ...       ...    ...      ...
# 250       251   48915  ZIORTZA - BOLIBAR   363.0     256.0    0.0    256.0
# 251       252   53000                NaN     NaN       NaN    NaN      NaN
# 252       253   53001                NaN     NaN       NaN    NaN      NaN
# 253       254   53048                NaN     NaN       NaN    NaN      NaN
# 254       255   53080                NaN     NaN       NaN    NaN      NaN
#
# ...

# %%
pd.read_csv(data_folder_in.format(iconos_zip))
# Out:
#                              Icono;code;name
# 0                    😀;U+1F600;grinning face
# 1      😃;U+1F603;grinning face with big eyes
# 2  😄;U+1F604;grinning face with smiling eyes
# 3        😁;U+;beaming face with smiling eyes

# %%
pd.read_csv(data_folder_in.format(iconos_zip), compression="zip")
# Out:
#                              Icono;code;name
# 0                    😀;U+1F600;grinning face
# 1      😃;U+1F603;grinning face with big eyes
# 2  😄;U+1F604;grinning face with smiling eyes
# 3        😁;U+;beaming face with smiling eyes

# %%
df = pd.read_csv(data_folder_in.format(iconos), sep=";")
df
# Out:
#   Icono     code                             name
# 0     😀  U+1F600                    grinning face
# 1     😃  U+1F603      grinning face with big eyes
# 2     😄  U+1F604  grinning face with smiling eyes
# 3     😁       U+   beaming face with smiling eyes

# %%
df.isnull()
# Out:
#    Icono   code   name
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
df = pd.read_csv(data_folder_in.format(iconos), sep=";", na_values=['U+'])
df
# Out:
#   Icono     code                             name
# 0     😀  U+1F600                    grinning face
# 1     😃  U+1F603      grinning face with big eyes
# 2     😄  U+1F604  grinning face with smiling eyes
# 3     😁      NaN   beaming face with smiling eyes

# %%
df.isnull()
# Out:
#    Icono   code   name
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False   True  False

# %%
df.dropna(inplace=True)
df
# Out:
#   Icono     code                             name
# 0     😀  U+1F600                    grinning face
# 1     😃  U+1F603      grinning face with big eyes
# 2     😄  U+1F604  grinning face with smiling eyes

# %%
import os
os.mkdir('./datos/out')
df.to_csv(data_folder_out.format(iconos))

# %%
pd.read_csv(data_folder_out.format(iconos))
# Out:
#    Unnamed: 0 Icono     code                             name
# 0           0     😀  U+1F600                    grinning face
# 1           1     😃  U+1F603      grinning face with big eyes
# 2           2     😄  U+1F604  grinning face with smiling eyes

# %%
df.to_csv(data_folder_out.format(iconos), index=False)

# %%
pd.read_csv(data_folder_out.format(iconos))
# Out:
#   Icono     code                             name
# 0     😀  U+1F600                    grinning face
# 1     😃  U+1F603      grinning face with big eyes
# 2     😄  U+1F604  grinning face with smiling eyes

# %%
df.to_csv(data_folder_out.format(iconos), index=False, sep=";")

# %%
pd.read_csv(data_folder_out.format(iconos), sep=";")
# Out:
#   Icono     code                             name
# 0     😀  U+1F600                    grinning face
# 1     😃  U+1F603      grinning face with big eyes
# 2     😄  U+1F604  grinning face with smiling eyes

# %%
df = pd.read_csv(data_folder_in.format(puntuaciones), sep=";")
df
# Out:
#   participante puntuacion                           pais
# 0         Jean        1,2                Francia; Bayona
# 1         Jhon        2,1  Estados Unidos; San Francisco
# 2       Julian        2,2                España; Bilbao

# %%
df.dtypes
# Out:
# participante    object
# puntuacion      object
# pais            object
# dtype: object

# %%
df['puntuacion'].sum()
# Out:
# '1,22,12,2'

# %%
df = pd.read_csv(data_folder_in.format(puntuaciones), sep=";", decimal=",")
df
# Out:
#   participante  puntuacion                           pais
# 0         Jean         1.2                Francia; Bayona
# 1         Jhon         2.1  Estados Unidos; San Francisco
# 2       Julian         2.2                España; Bilbao

# %%
df.dtypes
# Out:
# participante     object
# puntuacion      float64
# pais             object
# dtype: object

# %%
df['puntuacion'].sum()
# Out:
# 5.5

# %%
df
# Out:
#   participante  puntuacion                           pais
# 0         Jean         1.2                Francia; Bayona
# 1         Jhon         2.1  Estados Unidos; San Francisco
# 2       Julian         2.2                España; Bilbao

# %%
df.to_csv(data_folder_out.format(puntuaciones), index=False, sep=";", decimal=",")

# %% [markdown]
# # html
# * `attrs`: Sirve para indicar un filtro a la hora de buscar la tabla.

# %%
url = 'https://www.w3schools.com/html/html_tables.asp'

# %%
clientes_csv = "./datos/out/clientes.csv"

# %%
tables = pd.read_html(url)
len(tables)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 tables = pd.read_html(url)
#       2 len(tables)
#
# File ~\.conda\envs\datascience_openwebinars\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\.conda\envs\datascience_openwebinars\lib\site-packages\pandas\io\html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
# ...

# %%
tables
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 tables
#
# NameError: name 'tables' is not defined

# %%
df = tables[0]
df
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
df = pd.read_html(url, attrs={'id':'customers'})[0]
df
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df = pd.read_html(url, attrs={'id':'customers'})[0]
#       2 df
#
# File ~\.conda\envs\datascience_openwebinars\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\.conda\envs\datascience_openwebinars\lib\site-packages\pandas\io\html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
# ...

# %%
df.to_csv(clientes_csv, index=False)

# %% [markdown]
# # json
# * `path_or_buf`: El path del fichero json que puede ser http, ftp, s3, y un fichero.
# * `orient`: Indica el formato del archivo json
#   * `split` : `{index -> [index], columns -> [columns], data -> [values]}`
#   * `records` : `[{column -> value}, ... , {column -> value}]`
#   * `index` : `{index -> {column -> value}}`
#   * `columns` : `{column -> {index -> value}}`
#   * `values` : Valores en un array

# %%
pokedex = 'pokedex.json'

# %%
df = pd.read_json(data_folder_in.format(pokedex), orient='records')
df
# Out:
#       id                                               name             type  \
# 0      1  {'english': 'Bulbasaur', 'japanese': 'フシギダネ', ...  [Grass, Poison]
# 1      2  {'english': 'Ivysaur', 'japanese': 'フシギソウ', 'c...  [Grass, Poison]
# 2      3  {'english': 'Venusaur', 'japanese': 'フシギバナ', '...  [Grass, Poison]
# 3      4  {'english': 'Charmander', 'japanese': 'ヒトカゲ', ...           [Fire]
# 4      5  {'english': 'Charmeleon', 'japanese': 'リザード', ...           [Fire]
# ..   ...                                                ...              ...
# 804  805  {'english': 'Stakataka', 'japanese': 'ツンデツンデ',...    [Rock, Steel]
# 805  806  {'english': 'Blacephalon', 'japanese': 'ズガドーン'...    [Fire, Ghost]
# 806  807  {'english': 'Zeraora', 'japanese': 'ゼラオラ', 'ch...       [Electric]
# 807  808  {'english': 'Meltan', 'japanese': 'メルタン', 'chi...          [Steel]
# 808  809  {'english': 'Melmetal', 'japanese': 'メルメタル', '...          [Steel]
#
# ...

# %%
import json

# %%
with open(data_folder_in.format(pokedex), encoding='utf8') as file:
    data = json.load(file)
    
data
# Out:
# [{'id': 1,
#   'name': {'english': 'Bulbasaur',
#    'japanese': 'フシギダネ',
#    'chinese': '妙蛙种子',
#    'french': 'Bulbizarre'},
#   'type': ['Grass', 'Poison'],
#   'base': {'HP': 45,
#    'Attack': 49,
#    'Defense': 49,
#    'Sp. Attack': 65,
#    'Sp. Defense': 65,
#    'Speed': 45}},
#  {'id': 2,
#   'name': {'english': 'Ivysaur',
#    'japanese': 'フシギソウ',
#    'chinese': '妙蛙草',
#    'french': 'Herbizarre'},
#   'type': ['Grass', 'Poison'],
#   'base': {'HP': 60,
#    'Attack': 62,
#    'Defense': 63,
#    'Sp. Attack': 80,
#    'Sp. Defense': 80,
#    'Speed': 60}},
#  {'id': 3,
#   'name': {'english': 'Venusaur',
#    'japanese': 'フシギバナ',
#    'chinese': '妙蛙花',
#    'french': 'Florizarre'},
#   'type': ['Grass', 'Poison'],
#   'base': {'HP': 80,
#    'Attack': 82,
#    'Defense': 83,
#    'Sp. Attack': 100,
#    'Sp. Defense': 100,
#    'Speed': 80}},
#  {'id': 4,
#   'name': {'english': 'Charmander',
#    'japanese': 'ヒトカゲ',
#    'chinese': '小火龙',
# ...

# %%
df = pd.json_normalize(data)
df
# Out:
#       id             type name.english name.japanese name.chinese  \
# 0      1  [Grass, Poison]    Bulbasaur         フシギダネ         妙蛙种子
# 1      2  [Grass, Poison]      Ivysaur         フシギソウ          妙蛙草
# 2      3  [Grass, Poison]     Venusaur         フシギバナ          妙蛙花
# 3      4           [Fire]   Charmander          ヒトカゲ          小火龙
# 4      5           [Fire]   Charmeleon          リザード          火恐龙
# ..   ...              ...          ...           ...          ...
# 804  805    [Rock, Steel]    Stakataka        ツンデツンデ          垒磊石
# 805  806    [Fire, Ghost]  Blacephalon         ズガドーン         砰头小丑
# 806  807       [Electric]      Zeraora          ゼラオラ         捷拉奥拉
# 807  808          [Steel]       Meltan          メルタン          美录坦
# 808  809          [Steel]     Melmetal         メルメタル         美录梅塔
#
#       name.french  base.HP  base.Attack  base.Defense  base.Sp. Attack  \
# 0      Bulbizarre       45           49            49               65
# ...

# %% [markdown]
# # Consultando un API
# * [Api](https://rickandmortyapi.com/)

# %%
url = 'https://rickandmortyapi.com/api/character/'

# %%
from urllib.request import urlopen

response = urlopen(url)
json_data = response.read().decode('utf-8')

data = json.loads(json_data)

# %%
df = pd.json_normalize(data['results'])
df
# Out:
#     id                       name   status species  \
# 0    1               Rick Sanchez    Alive   Human
# 1    2                Morty Smith    Alive   Human
# 2    3               Summer Smith    Alive   Human
# 3    4                 Beth Smith    Alive   Human
# 4    5                Jerry Smith    Alive   Human
# 5    6  Abadango Cluster Princess    Alive   Alien
# 6    7           Abradolf Lincler  unknown   Human
# 7    8           Adjudicator Rick     Dead   Human
# 8    9            Agency Director     Dead   Human
# 9   10                 Alan Rails     Dead   Human
# 10  11            Albert Einstein     Dead   Human
# 11  12                  Alexander     Dead   Human
# 12  13               Alien Googah  unknown   Alien
# 13  14                Alien Morty  unknown   Alien
# 14  15                 Alien Rick  unknown   Alien
# 15  16               Amish Cyborg     Dead   Alien
# 16  17                      Annie    Alive   Human
# ...

# %%
df.T.to_json(data_folder_out.format('ricky.json'))

# %%
pd.read_json(data_folder_out.format('ricky.json'))
# Out:
#                                                               0   \
# id                                                             1
# name                                                Rick Sanchez
# status                                                     Alive
# species                                                    Human
# type
# gender                                                      Male
# image          https://rickandmortyapi.com/api/character/avat...
# episode        [https://rickandmortyapi.com/api/episode/1, ht...
# url                  https://rickandmortyapi.com/api/character/1
# created                                 2017-11-04T18:48:46.250Z
# origin.name                                        Earth (C-137)
# origin.url            https://rickandmortyapi.com/api/location/1
# location.name                                   Citadel of Ricks
# location.url          https://rickandmortyapi.com/api/location/3
#
# ...

# %% [markdown]
# # pdf
# Se usara la libreria [tabula-py](https://pypi.org/project/tabula-py/)
#
# [Ejemplo oficial](https://nbviewer.jupyter.org/github/chezou/tabula-py/blob/master/examples/tabula_example.ipynb)
#
# [PDF para probar tabula](https://github.com/chezou/tabula-py/raw/master/tests/resources/data.pdf)

# %%
import tabula

# %%
url = "https://github.com/chezou/tabula-py/raw/master/tests/resources/data.pdf"

# %%
df = tabula.read_pdf(url, stream=True, pages='1')

# %%
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# # SQL
#
# * `to_sql`:
#  * `if_exists`: `{‘fail’, ‘replace’, ‘append’}`, defecto `‘fail’`

# %%
database = 'chinook.db'

# %%
cnx = sqlite3.connect(data_folder_in.format(database))

# %%
df = pd.read_sql_query("SELECT * FROM playlists", cnx)
df
# Out:
#     PlaylistId                        Name
# 0            1                       Music
# 1            2                      Movies
# 2            3                    TV Shows
# 3            4                  Audiobooks
# 4            5                  90’s Music
# 5            6                  Audiobooks
# 6            7                      Movies
# 7            8                       Music
# 8            9                Music Videos
# 9           10                    TV Shows
# 10          11             Brazilian Music
# 11          12                   Classical
# 12          13   Classical 101 - Deep Cuts
# 13          14  Classical 101 - Next Steps
# 14          15  Classical 101 - The Basics
# 15          16                      Grunge
# 16          17         Heavy Metal Classic
# 17          18                 On-The-Go 1

# %%
df['Name'] = df['Name'].str.lower()

# %%
df
# Out:
#     PlaylistId                        Name
# 0            1                       music
# 1            2                      movies
# 2            3                    tv shows
# 3            4                  audiobooks
# 4            5                  90’s music
# 5            6                  audiobooks
# 6            7                      movies
# 7            8                       music
# 8            9                music videos
# 9           10                    tv shows
# 10          11             brazilian music
# 11          12                   classical
# 12          13   classical 101 - deep cuts
# 13          14  classical 101 - next steps
# 14          15  classical 101 - the basics
# 15          16                      grunge
# 16          17         heavy metal classic
# 17          18                 on-the-go 1

# %%
df.to_sql('playlists', con=cnx, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-10-9bb865c3c475> in <module>
# ----> 1 df.to_sql('playlists', con=cnx, if_exists='append')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1732         )
# ...

# %%
df.to_sql('playlists', con=cnx, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-12-0d80c2e2c28e> in <module>
# ----> 1 df.to_sql('playlists', con=cnx, if_exists='append', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
# ...

# %%
df['PlaylistId'] = df['PlaylistId'] + 20
df
# Out:
#     PlaylistId                        Name
# 0           81                       music
# 1           82                      movies
# 2           83                    tv shows
# 3           84                  audiobooks
# 4           85                  90’s music
# 5           86                  audiobooks
# 6           87                      movies
# 7           88                       music
# 8           89                music videos
# 9           90                    tv shows
# 10          91             brazilian music
# 11          92                   classical
# 12          93   classical 101 - deep cuts
# 13          94  classical 101 - next steps
# 14          95  classical 101 - the basics
# 15          96                      grunge
# 16          97         heavy metal classic
# 17          98                 on-the-go 1

# %%
df.to_sql('playlists', con=cnx, if_exists='append', index=False, index_label='PlaylistId')

# %%
df = pd.read_sql_query("SELECT * FROM playlists", cnx)
df
# Out:
#     PlaylistId                        Name
# 0            1                       Music
# 1            2                      Movies
# 2            3                    TV Shows
# 3            4                  Audiobooks
# 4            5                  90’s Music
# 5            6                  Audiobooks
# 6            7                      Movies
# 7            8                       Music
# 8            9                Music Videos
# 9           10                    TV Shows
# 10          11             Brazilian Music
# 11          12                   Classical
# 12          13   Classical 101 - Deep Cuts
# 13          14  Classical 101 - Next Steps
# 14          15  Classical 101 - The Basics
# 15          16                      Grunge
# 16          17         Heavy Metal Classic
# 17          18                 On-The-Go 1
# 18          81                       music
# 19          82                      movies
# 20          83                    tv shows
# ...

# %%
df['Name'] = df['Name'].str.lower()
df
# Out:
#     PlaylistId                        Name
# 0            1                       music
# 1            2                      movies
# 2            3                    tv shows
# 3            4                  audiobooks
# 4            5                  90’s music
# 5            6                  audiobooks
# 6            7                      movies
# 7            8                       music
# 8            9                music videos
# 9           10                    tv shows
# 10          11             brazilian music
# 11          12                   classical
# 12          13   classical 101 - deep cuts
# 13          14  classical 101 - next steps
# 14          15  classical 101 - the basics
# 15          16                      grunge
# 16          17         heavy metal classic
# 17          18                 on-the-go 1
# 18          81                       music
# 19          82                      movies
# 20          83                    tv shows
# ...

# %%
df.to_sql('playlists', con=cnx, if_exists='replace', index=False, index_label='PlaylistId')

# %%
df = pd.read_sql_query("SELECT * FROM playlists", cnx)
df
# Out:
#     PlaylistId                        Name
# 0            1                       music
# 1            2                      movies
# 2            3                    tv shows
# 3            4                  audiobooks
# 4            5                  90’s music
# 5            6                  audiobooks
# 6            7                      movies
# 7            8                       music
# 8            9                music videos
# 9           10                    tv shows
# 10          11             brazilian music
# 11          12                   classical
# 12          13   classical 101 - deep cuts
# 13          14  classical 101 - next steps
# 14          15  classical 101 - the basics
# 15          16                      grunge
# 16          17         heavy metal classic
# 17          18                 on-the-go 1
# 18          81                       music
# 19          82                      movies
# 20          83                    tv shows
# ...

# %%
df = pd.read_sql_query("""
    SELECT * FROM playlists p, playlist_track pt
    WHERE p.PlaylistId = pt.PlaylistId
""", cnx)
df
# Out:
#       PlaylistId                 Name  PlaylistId  TrackId
# 0              1                music           1     3402
# 1              1                music           1     3389
# 2              1                music           1     3390
# 3              1                music           1     3391
# 4              1                music           1     3392
# ...          ...                  ...         ...      ...
# 8710          17  heavy metal classic          17     2094
# 8711          17  heavy metal classic          17     2095
# 8712          17  heavy metal classic          17     2096
# 8713          17  heavy metal classic          17     3290
# 8714          18          on-the-go 1          18      597
#
# [8715 rows x 4 columns]

# %%
df.to_csv(data_folder_out.format('chinook.csv'), index=False, sep=";", decimal=",")

# %% [markdown]
# # Pickle
# * `compression`: `{‘infer’, ‘gzip’, ‘bz2’, ‘zip’, ‘xz’, None}`, defecto `‘infer’`

# %%
iconos = 'iconos.csv'
pkl = 'iconos.pkl'

# %%
df = pd.read_csv(data_folder_in.format(iconos), sep=";")
df
# Out:
#   Icono     code                             name
# 0     😀  U+1F600                    grinning face
# 1     😃  U+1F603      grinning face with big eyes
# 2     😄  U+1F604  grinning face with smiling eyes
# 3     😁       U+   beaming face with smiling eyes

# %%
df.to_pickle(data_folder_out.format(pkl))

# %%
df = None

# %%
import pickle
df = pickle.load(open(data_folder_out.format(pkl), "rb" ) )
df
# Out:
#   Icono     code                             name
# 0     😀  U+1F600                    grinning face
# 1     😃  U+1F603      grinning face with big eyes
# 2     😄  U+1F604  grinning face with smiling eyes
# 3     😁       U+   beaming face with smiling eyes

# %%
pickle.dump(df, open( data_folder_out.format(pkl), "wb" ) )
df = None

# %%
df = pickle.load(open(data_folder_out.format(pkl), "rb" ) )
df
# Out:
#   Icono     code                             name
# 0     😀  U+1F600                    grinning face
# 1     😃  U+1F603      grinning face with big eyes
# 2     😄  U+1F604  grinning face with smiling eyes
# 3     😁       U+   beaming face with smiling eyes
